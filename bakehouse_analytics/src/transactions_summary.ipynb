# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"create schema if not exists {schema}")
spark.sql(f"USE SCHEMA {schema}")

# %%
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
print(catalog)
print(schema)

# %%
spark.read.table("samples.nyctaxi.trips")

# %%
spark.sql(f"""create table if not exists {catalog}.{schema}.customer_360 as  
          select country,
          count(*) as number_of_customer,
          count_if(gender = 'Female') as number_of_female,
          count_if(gender = 'Male') as number_of_male
          from samples.bakehouse.sales_customers
          group by country """)

# %%
print("this is the clone of customers_360 ")
